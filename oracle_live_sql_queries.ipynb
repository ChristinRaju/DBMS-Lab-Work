# %% [markdown]
# ## 🏢 Department Table
# This query displays all departments and their locations.

# %%
SELECT
    DEPTID,
    DEPTNAME,
    DEPTLOC
FROM
    DEPARTMENT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 🧑‍💼 Employee Table
# This query displays all employees and their department IDs, along with job details and salary.

# %%
SELECT
    EMPID,
    EMPNAME,
    DOB,
    DOJ,
    JOB,
    SALARY,
    DEPTID
FROM
    EMPLOYEE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📦 Product Table
# This query displays all products and their prices.

# %%
SELECT
    PRODID,
    PRODNAME,
    PRICE
FROM
    PRODUCT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 💰 Sales Table
# This query displays all sales transactions.

# %%
SELECT
    SALESID,
    SALESDATE,
    QUANTITY,
    EMPID,
    PRODID
FROM
    SALES

# %% [markdown]
# ![image.png](attachment:image.png)
